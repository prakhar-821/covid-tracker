# %%
import gspread
import snscrape.modules.twitter as sntwitter
import pandas as pd

# %%
gc = gspread.oauth()

# %%
cities_list = ['Jaipur','Lucknow','Kolkata','Thane']

for city in cities_list:

    # Creating list to append tweet data to
    tweets_list1 = []

    q_str = "verified {0} (bed OR beds OR icu OR oxygen OR ventilator OR ventilators OR k) -'not verified' -'unverified' -'needed' -'need' -'needs' -'required' -'require' -'requires' -'requirement' -'requirements'"

    # Using TwitterSearchScraper to scrape data and append tweets to list
    for i,tweet in enumerate(sntwitter.TwitterSearchScraper(q_str.format(city) + ' since:2020-04-25').get_items()):
        if i>100:
            break
        tweets_list1.append([tweet.date, tweet.content, tweet.username])

    # Creating a dataframe from the tweets list above 
    tweets_df1 = pd.DataFrame(tweets_list1, columns=['Datetime', 'Text', 'Username'])
    tweets_df1['Datetime'] = tweets_df1['Datetime'].astype(str)
    tweets_df1['Datetime'] = tweets_df1['Datetime'].apply(lambda x : x[:19])
    tweets_df1 = tweets_df1[:50]
    print(city)
    sh = gc.open("Covid Tracker").worksheet(city)
    sh.resize(1)
    for i, row in tweets_df1.iterrows():
        sh.append_row(row.values.tolist())
    #     print(i)
        print(row)
# Out:
# Jaipur
# Datetime                                  2021-04-25 04:37:22
# Text        Please contact the below numbers in case of ox...
# Username                                        sarcasm_sasta
# Name: 0, dtype: object
# Datetime                                  2021-04-25 04:26:43
# Text        Verified Oxygen resources in #Jaipur ~\n1). An...
# Username                                          SSRMansur21
# Name: 1, dtype: object
# Datetime                                  2021-04-25 04:23:02
# Text        Hospital normal bed with oxygen available in j...
# Username                                         reloadedsoni
# Name: 2, dtype: object
# Datetime                                  2021-04-25 04:12:34
# Text        Verified Oxygen resources in #Jaipur ~\n1). An...
# Username                                         imjayeshvyas
# Name: 3, dtype: object
# Datetime                                  2021-04-25 03:41:30
# Text        Verified Oxygen resources in Jaipur ~\n1). Ana...
# Username                                         imeghamishra
# Name: 4, dtype: object
# Datetime                                  2021-04-25 03:01:32
# Text        Guys..I m making an excel sheet fr Jaipur and ...
# Username                                        arnab_goswmai
# Name: 5, dtype: object
# Datetime                                  2021-04-24 21:42:42
# Text        #राजस्थान में ऑक्सीजन की किल्लत या अस्पताल में...
# Username                                       RakshitYadav25
# Name: 6, dtype: object
# Datetime                                  2021-04-24 18:57:22
# Text        @riya__rathore #Jaipur Vivekanand swasthay sew...
# Username                                         shubham01972
# Name: 7, dtype: object
# Datetime                                  2021-04-24 18:16:41
# Text        Oxygen beds availability in jaipur\n\n#Verifie...
# Username                                           __dewdrops
# Name: 8, dtype: object
# Datetime                                  2021-04-24 17:35:41
# Text        Requested by a follower on Instagram\n❗❗please...
# Username                                             Baba_Chu
# Name: 9, dtype: object
# Datetime                                  2021-04-24 17:34:10
# Text        Covid Related Authentic Live Information Verif...
# Username                                      ashishchaturved
# Name: 10, dtype: object
# Datetime                                  2021-04-24 16:33:04
# Text        Oxygen beds #Jaipur \n#Verified https://t.co/x...
# Username                                             Q_erty24
# Name: 11, dtype: object
# Datetime                                  2021-04-24 16:29:00
# Text        #Jaipur Vivekanand swasthay sewa samiti hospit...
# Username                                              Sidd__X
# Name: 12, dtype: object
# Datetime                                  2021-04-24 16:25:30
# Text        @siddhaaaarrth Vivekanand swasthay sewa samiti...
# Username                                            pradverse
# Name: 13, dtype: object
# Datetime                                  2021-04-24 16:17:07
# Text        Vivekanand swasthay sewa samiti hospital- 9413...
# Username                                           Sorry_Shwe
# Name: 14, dtype: object
# Datetime                                  2021-04-24 15:48:55
# Text        @amicroinvestor #JAIPUR sources for - beds, re...
# Username                                      Katappa87877989
# Name: 15, dtype: object
# Datetime                                  2021-04-24 15:48:09
# Text        @amicroinvestor #JAIPUR sources for - beds, re...
# Username                                      Katappa87877989
# Name: 16, dtype: object
# Datetime                                  2021-04-24 15:14:43
# Text        Plz amplify for anyone in or around Jaipur or ...
# Username                                       PareekShivaani
# Name: 17, dtype: object
# Datetime                                  2021-04-24 14:46:36
# Text        #jaipur #oxygen #OxygenCylinder #verified  8:0...
# Username                                            halfdhruv
# Name: 18, dtype: object
# Datetime                                  2021-04-24 14:39:33
# Text        Beds Available (Oxygen Beds )\n\nLocation: Jai...
# Username                                      VishveshKardani
# Name: 19, dtype: object
# Datetime                                  2021-04-24 14:24:13
# Text        @siddhaaaarrth @Singhlicious ICU Ventilators A...
# Username                                            Oye_ladki
# Name: 20, dtype: object
# Datetime                                  2021-04-24 14:17:45
# Text        Location; Jaipur\n\nBEDS NORMAL/OXYGEN availab...
# Username                                         covid19help_
# Name: 21, dtype: object
# Datetime                                  2021-04-24 14:10:40
# Text        Oxygen beds available in Jaipur\n#Verified #Ja...
# Username                                           __dewdrops
# Name: 22, dtype: object
# Datetime                                  2021-04-24 13:48:25
# Text        Hospital beds availability \n\n#Jaipur #Rajast...
# Username                                         EvankHell_rm
# Name: 23, dtype: object
# Datetime                                  2021-04-24 13:47:36
# Text        Location; Jaipur\n\nBEDS NORMAL/OXYGEN availab...
# Username                                       thedirtysprite
# Name: 24, dtype: object
# Datetime                                  2021-04-24 13:39:35
# Text        Rajasthan - Ajmer, Bundi, Jaipur, Udaipur, Kot...
# Username                                           aprrillll_
# Name: 25, dtype: object
# Datetime                                  2021-04-24 13:32:26
# Text        @M_arioooooo @siddhaaaarrth Bed/Ventilators/#O...
# Username                                          _Kushagra_G
# Name: 26, dtype: object
# Datetime                                  2021-04-24 13:04:01
# Text        ‼ 3 OXYGEN BEDS AVAILABLE IN JAIPUR‼\nlocation...
# Username                                           aanandvedu
# Name: 27, dtype: object
# Datetime                                  2021-04-24 12:46:28
# Text        @CovidSupportIn forwarded msg pls check.. \n\n...
# Username                                              hsd1986
# Name: 28, dtype: object
# Datetime                                  2021-04-24 12:44:26
# Text        @Purana_500 @_lokeshsharma forwarded msg pls c...
# Username                                              hsd1986
# Name: 29, dtype: object
# Datetime                                  2021-04-24 12:43:18
# Text        @chaudharynikhil forwarded msg pls check. \n\n...
# Username                                              hsd1986
# Name: 30, dtype: object
# Datetime                                  2021-04-24 12:42:41
# Text        @NaveenRKukreja forwarded msg pls check. \n\nR...
# Username                                              hsd1986
# Name: 31, dtype: object
# Datetime                                  2021-04-24 12:41:14
# Text        Beds Available (Oxygen Beds )\n\nLocation: Jai...
# Username                                        HarshSonkhiya
# Name: 32, dtype: object
# Datetime                                  2021-04-24 12:39:16
# Text        Beds Available (Oxygen Beds )\n\nLocation: Jai...
# Username                                      livechic_Mishti
# Name: 33, dtype: object
# Datetime                                  2021-04-24 12:33:30
# Text        ‼️ VERIFIED ‼️@Jaipur\nPlease check Tweet 👇👇 h...
# Username                                          The_DeepakP
# Name: 34, dtype: object
# Datetime                                  2021-04-24 12:25:07
# Text        Radha nursing home jhotwara Jaipur \nRajasthan...
# Username                                       rahulthevillan
# Name: 35, dtype: object
# Datetime                               2021-04-24 12:11:48
# Text        #jaipur #verified #bed https://t.co/v0eNzp0JmM
# Username                                    AGuyHasNoName3
# Name: 36, dtype: object
# Datetime                                  2021-04-24 11:59:40
# Text        Beds Available (Oxygen Beds )\n\nLocation: Jai...
# Username                                            prabhgun_
# Name: 37, dtype: object
# Datetime                                  2021-04-24 11:59:27
# Text        @froggityfroggo Beds Available (Oxygen Beds )\...
# Username                                      SaraSushant2021
# Name: 38, dtype: object
# Datetime                                  2021-04-24 11:58:24
# Text        Beds Available (Oxygen Beds )\n\nLocation: Jai...
# Username                                            Keshu__10
# Name: 39, dtype: object
# Datetime                                  2021-04-24 11:52:48
# Text        @_imanishgaur @RajGovOfficial Type "Oxygen Jai...
# Username                                        khurafatijaat
# Name: 40, dtype: object
# Datetime                                  2021-04-24 11:52:09
# Text        @aweessomme @Arjun_Mehar Type "Oxygen Jaipur" ...
# Username                                        khurafatijaat
# Name: 41, dtype: object
# Datetime                                  2021-04-24 11:30:57
# Text        Oxygen beds #Jaipur \n#Verified https://t.co/8...
# Username                                             Q_erty24
# Name: 42, dtype: object
# Datetime                                  2021-04-24 11:17:21
# Text        https://t.co/WsjQ5EqgKp\nFind Pan India resour...
# Username                                        saurabh_sam96
# Name: 43, dtype: object
# Datetime                                  2021-04-24 11:16:08
# Text        3 ICU beds  with high flow oxygen facility  av...
# Username                                      MridulKhandel18
# Name: 44, dtype: object
# Datetime                                  2021-04-24 10:30:15
# Text        Sevayatan Hospital\n01412220240 verified numbe...
# Username                                              akiham_
# Name: 45, dtype: object
# Datetime                                  2021-04-24 10:12:06
# Text        #JAIPUR\n\n#Oxygen , medicine supply,  availab...
# Username                                      AmitWankhade999
# Name: 46, dtype: object
# Datetime                                  2021-04-24 09:25:12
# Text        #beds available in #Jaipur\n#Verified by me ju...
# Username                                      pahaadi__chhori
# Name: 47, dtype: object
# Datetime                                  2021-04-24 09:20:44
# Text        Guys bed available in Jaipur\nI've verified ju...
# Username                                      pahaadi__chhori
# Name: 48, dtype: object
# Datetime                                  2021-04-24 09:14:13
# Text        Normal beds available at Vedanta Hospital, Ajm...
# Username                                             Q_erty24
# Name: 49, dtype: object
# Lucknow
# Datetime                                  2021-04-25 04:48:40
# Text        #oxygen available \nin #lucknow \n\nVerified ✅...
# Username                                            pradverse
# Name: 0, dtype: object
# Datetime                                  2021-04-25 04:47:01
# Text        #Oxygen Can Available in  #Lucknow \n\nKindly ...
# Username                                       iamnowayfunnyy
# Name: 1, dtype: object
# Datetime                                  2021-04-25 04:43:21
# Text        ICU Beds &amp; Ventilator in Lucknow.\n#Verifi...
# Username                                        imvarunsrvstv
# Name: 2, dtype: object
# Datetime                                  2021-04-25 04:25:14
# Text        @PrernaBhalla89 @myogiadityanath @CMOfficeUP T...
# Username                                          hmdeglurkar
# Name: 3, dtype: object
# Datetime                                  2021-04-25 04:19:41
# Text        Verified: Oxygen cans in Lucknow. https://t.co...
# Username                                               faltoo
# Name: 4, dtype: object
# Datetime                                  2021-04-25 04:12:23
# Text        #lucknow #oxygen #cylinders #refill #available...
# Username                                         spokenatlast
# Name: 5, dtype: object
# Datetime                                  2021-04-25 04:10:25
# Text        Glad that I managed to help someone get Oxygen...
# Username                                        SarcasmPandit
# Name: 6, dtype: object
# Datetime                                  2021-04-25 04:06:39
# Text        Verified Oxygen Resources for Covid - Pan Indi...
# Username                                            niks__712
# Name: 7, dtype: object
# Datetime                                  2021-04-25 04:01:06
# Text        # Covid related data\nPl help with verified da...
# Username                                      jyotiagrawalma1
# Name: 8, dtype: object
# ---------------------------------------------------------------------------
# APIError                                  Traceback (most recent call last)
# <ipython-input-14-0705907e1112> in <module>
#      23     sh.resize(1)
#      24     for i, row in tweets_df1.iterrows():
# ---> 25         sh.append_row(row.values.tolist())
#      26     #     print(i)
#      27         print(row)
#
# C:\ProgramData\Anaconda3\lib\site-packages\gspread\models.py in append_row(self, values, value_input_option, insert_data_option, table_range)
#    1463
#    1464         """
# -> 1465         return self.append_rows(
#    1466             [values],
#    1467             value_input_option=value_input_option,
#
# C:\ProgramData\Anaconda3\lib\site-packages\gspread\models.py in append_rows(self, values, value_input_option, insert_data_option, table_range)
#    1505         body = {'values': values}
#    1506
# -> 1507         return self.spreadsheet.values_append(range_label, params, body)
#    1508
#    1509     def insert_row(self, values, index=1, value_input_option='RAW'):
#
# C:\ProgramData\Anaconda3\lib\site-packages\gspread\models.py in values_append(self, range, params, body)
#     163         """
#     164         url = SPREADSHEET_VALUES_APPEND_URL % (self.id, quote(range))
# --> 165         r = self.client.request('post', url, params=params, json=body)
#     166         return r.json()
#     167
#
# C:\ProgramData\Anaconda3\lib\site-packages\gspread\client.py in request(self, method, endpoint, params, data, json, files, headers)
#      74             return response
#      75         else:
# ---> 76             raise APIError(response)
#      77
#      78     def list_spreadsheet_files(self, title=None):
#
# APIError: {'code': 429, 'message': "Quota exceeded for quota metric 'Write requests' and limit 'Write requests per minute per user' of service 'sheets.googleapis.com' for consumer 'project_number:1025394391279'.", 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.ErrorInfo', 'reason': 'RATE_LIMIT_EXCEEDED', 'domain': 'googleapis.com', 'metadata': {'quota_metric': 'sheets.googleapis.com/write_requests', 'quota_limit': 'WriteRequestsPerMinutePerUser', 'consumer': 'projects/1025394391279', 'service': 'sheets.googleapis.com'}}]}
